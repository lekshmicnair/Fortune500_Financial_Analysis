# %%
import pandas as pd

# %%
fort1000_file = "Data/Fortune1000-final.csv"
fort1000_df = pd.read_csv(fort1000_file, encoding = 'ISO-8859-1')
fort1000_df.head()
# Out:
#    rank               title Previous Rank Revenues ($M) Revenue Change  \
# 0     1             Walmart             1     $500,343           3.00%
# 1     2         Exxon Mobil             4     $244,363          17.40%
# 2     3  Berkshire Hathaway             2     $242,137           8.30%
# 3     4               Apple             3     $229,234           6.30%
# 4     5  UnitedHealth Group             6     $201,159           8.80%
#
#   Profits ($M) Profit Change Assets ($M) Mkt Value as of 3/29/18 ($M)  \
# 0   $9,862.00        -27.70%   $204,522                     $263,563
# 1  $19,710.00        151.40%   $348,691                     $316,157
# 2  $44,940.00         86.70%   $702,095                     $492,008
# 3  $48,351.00          5.80%   $375,319                     $851,318
# 4  $10,558.00         50.50%   $139,058                     $207,080
#
#    Employees                  CEO  \
# 0  2,300,000  C. Douglas McMillon
# 1     71,200      Darren W. Woods
# 2    377,000    Warren E. Buffett
# 3    123,000      Timothy D. Cook
# 4    260,000    David S. Wichmann
#
#                                         CEO Title       Sector  \
# 0  President, Chief Executive Officer &  Director    Retailing
# 1             Chairman &  Chief Executive Officer       Energy
# 2  Chairman, President &  Chief Executive Officer   Financials
# 3             Chairman &  Chief Executive Officer   Technology
# 4             Chairman &  Chief Executive Officer  Health Care
#
#                                    Industry Years on Fortune 500 List  \
# 0                     General Merchandisers                        24
# 1                        Petroleum Refining                        24
# 2  Insurance: Property and Casualty (Stock)                        24
# 3               Computers, Office Equipment                        24
# 4   Health Care: Insurance and Managed Care                        24
#
#           City State   Latitude   Longitude
# 0  Bentonville    AR  36.372854  -94.208817
# 1       Irving    TX  32.814018  -96.948894
# 2        Omaha    NE  41.256537  -95.934503
# 3    Cupertino    CA  37.322998 -122.032182
# 4   Minnetonka    MN  44.921184  -93.468749

# %%
fort1000_reduced = fort1000_df[['title', 'Sector', 'Industry', 'City', 'State', 'Latitude', 'Longitude']]
fort1000_reduced.rename(columns = {'title': 'Company Name'}, inplace=True)

fort1000_reduced.head()
# Out:
# C:\Users\Alex\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          Company Name       Sector                                  Industry  \
# 0             Walmart    Retailing                     General Merchandisers
# 1         Exxon Mobil       Energy                        Petroleum Refining
# 2  Berkshire Hathaway   Financials  Insurance: Property and Casualty (Stock)
# 3               Apple   Technology               Computers, Office Equipment
# 4  UnitedHealth Group  Health Care   Health Care: Insurance and Managed Care
#
#           City State   Latitude   Longitude
# 0  Bentonville    AR  36.372854  -94.208817
# 1       Irving    TX  32.814018  -96.948894
# 2        Omaha    NE  41.256537  -95.934503
# 3    Cupertino    CA  37.322998 -122.032182
# 4   Minnetonka    MN  44.921184  -93.468749

# %%
fort500_file = "Data/fortune500.csv"
fort500_df = pd.read_csv(fort500_file, encoding = 'ISO-8859-1')
fort500_df.head()
# Out:
#    Rank Company Name Number of Employees Change in Rank Revenues ($millions)  \
# 0     1      Walmart           2,200,000              -            $523,964
# 1     2   Amazon.com             798,000              3            $280,522
# 2     3  Exxon Mobil              74,900             -1            $264,938
# 3     4        Apple             137,000             -1            $260,174
# 4     5   CVS Health             290,000              3            $256,776
#
#   Revenue Change Profits ($millions) Profit Change Assets ($millions)  \
# 0          1.90%         $14,881.00        123.10%          $236,495
# 1         20.50%         $11,588.00         15.00%          $225,248
# 2         -8.70%         $14,340.00        -31.20%          $362,597
# 3         -2.00%         $55,256.00         -7.20%          $338,516
# 4         32.00%          $6,634.00              -          $222,449
#
#   Market Value As of 3/31/20 ($m)
# 0                       $321,803
# 1                       $970,680
# 2                       $160,696
# 3                     $1,112,641
# 4                        $77,376

# %%
fort500_final = pd.merge(fort500_df, fort1000_reduced, how="left", on=['Company Name', 'Company Name'])
fort500_final.head()
# Out:
#    Rank Company Name Number of Employees Change in Rank Revenues ($millions)  \
# 0     1      Walmart           2,200,000              -            $523,964
# 1     2   Amazon.com             798,000              3            $280,522
# 2     3  Exxon Mobil              74,900             -1            $264,938
# 3     4        Apple             137,000             -1            $260,174
# 4     5   CVS Health             290,000              3            $256,776
#
#   Revenue Change Profits ($millions) Profit Change Assets ($millions)  \
# 0          1.90%         $14,881.00        123.10%          $236,495
# 1         20.50%         $11,588.00         15.00%          $225,248
# 2         -8.70%         $14,340.00        -31.20%          $362,597
# 3         -2.00%         $55,256.00         -7.20%          $338,516
# 4         32.00%          $6,634.00              -          $222,449
#
#   Market Value As of 3/31/20 ($m)       Sector  \
# 0                       $321,803     Retailing
# 1                       $970,680     Retailing
# 2                       $160,696        Energy
# 3                     $1,112,641    Technology
# 4                        $77,376   Health Care
#
#                                    Industry         City State   Latitude  \
# 0                     General Merchandisers  Bentonville    AR  36.372854
# 1           Internet Services and Retailing      Seattle    WA  47.606209
# 2                        Petroleum Refining       Irving    TX  32.814018
# 3               Computers, Office Equipment    Cupertino    CA  37.322998
# 4  Health Care: Pharmacy and Other Services   Woonsocket    RI  42.002876
#
#     Longitude
# 0  -94.208817
# 1 -122.332071
# 2  -96.948894
# 3 -122.032182
# 4  -71.514784

# %%
fort500_final.to_csv("Data/Fortune500_final.csv")
